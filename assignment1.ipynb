# %% [markdown]
# Load Dataset and convert to html

# %%
import re
from bs4 import BeautifulSoup
import requests
import numpy as np
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
url="https://en.wikipedia.org/wiki/Al_Ahly_SC"
page = requests.get(url)
html_content = BeautifulSoup(page.text, 'html')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\Ahmed
# [nltk_data]     Ali\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Ahmed
# [nltk_data]     Ali\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\Ahmed
# [nltk_data]     Ali\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
html_content
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-feature-night-mode-disabled skin-night-mode-clientpref-0 vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Al Ahly SC - Wikipedia</title>
# ...

# %%
class preprocessing:
    def __init__(self,text):
        self.text=text.text
        self.words=None
    def clear(self):
        clean = re.compile('<.*?>')
        self.text =  re.sub(clean, '', self.text)
        self.text= re.sub(r"[^a-zA-Z]"," ",self.text)
        self.text = re.sub(r'\s+', ' ', self.text)
    def Normalization(self):
        self.text=self.text.lower()
        print(self.text)
    def Tokenization(self):
        self.words = word_tokenize(self.text)
        print(self.words)
    def del_stop_words(self):
           stop_words = set(stopwords.words('english'))
           self.words=[word for word in self.words if (word not in stop_words)]
           print(self.words)
    def Lemmatization(self):
        lemmatizer = WordNetLemmatizer()
        self.words = [lemmatizer.lemmatize(word) for word in self.words]
        print(self.words)
    def unique_words(self):
        return set(self.words)
    
    def del_char (self):
        self.words=[word for word in self.words if (len(word)>1)]

# %%
pr=preprocessing(html_content)

# %%
pr.clear()

# %%
pr.Normalization()
# Out:
#  al ahly sc wikipedia jump to content main menu main menu move to sidebar hide navigation main pagecontentscurrent eventsrandom articleabout wikipediacontact usdonate contribute helplearn to editcommunity portalrecent changesupload file search search create account log in personal tools create account log in pages for logged out editors learn more contributionstalk contents move to sidebar hide top history toggle history subsection establishment and start of the club first titles dominating the league first participation in african championships african success arab tournament success boycotting caf golden era mahmoud taher era mahmoud el khatib era return to african success rivalries supporters toggle supporters subsection ultras ahlawy other supporting groups port said stadium riot anthem grounds toggle grounds subsection mokhtar el tetsh stadium training ground cairo international stadium al ahly we al salam stadium zayed city stadium media kits and crest toggle kits and crest sub
# ...

# %%
pr.Tokenization()
# Out:
# ['al', 'ahly', 'sc', 'wikipedia', 'jump', 'to', 'content', 'main', 'menu', 'main', 'menu', 'move', 'to', 'sidebar', 'hide', 'navigation', 'main', 'pagecontentscurrent', 'eventsrandom', 'articleabout', 'wikipediacontact', 'usdonate', 'contribute', 'helplearn', 'to', 'editcommunity', 'portalrecent', 'changesupload', 'file', 'search', 'search', 'create', 'account', 'log', 'in', 'personal', 'tools', 'create', 'account', 'log', 'in', 'pages', 'for', 'logged', 'out', 'editors', 'learn', 'more', 'contributionstalk', 'contents', 'move', 'to', 'sidebar', 'hide', 'top', 'history', 'toggle', 'history', 'subsection', 'establishment', 'and', 'start', 'of', 'the', 'club', 'first', 'titles', 'dominating', 'the', 'league', 'first', 'participation', 'in', 'african', 'championships', 'african', 'success', 'arab', 'tournament', 'success', 'boycotting', 'caf', 'golden', 'era', 'mahmoud', 'taher', 'era', 'mahmoud', 'el', 'khatib', 'era', 'return', 'to', 'african', 'success', 'rivalries', 'supporters', 't
# ...

# %%
pr.del_stop_words()
# Out:
# ['al', 'ahly', 'sc', 'wikipedia', 'jump', 'content', 'main', 'menu', 'main', 'menu', 'move', 'sidebar', 'hide', 'navigation', 'main', 'pagecontentscurrent', 'eventsrandom', 'articleabout', 'wikipediacontact', 'usdonate', 'contribute', 'helplearn', 'editcommunity', 'portalrecent', 'changesupload', 'file', 'search', 'search', 'create', 'account', 'log', 'personal', 'tools', 'create', 'account', 'log', 'pages', 'logged', 'editors', 'learn', 'contributionstalk', 'contents', 'move', 'sidebar', 'hide', 'top', 'history', 'toggle', 'history', 'subsection', 'establishment', 'start', 'club', 'first', 'titles', 'dominating', 'league', 'first', 'participation', 'african', 'championships', 'african', 'success', 'arab', 'tournament', 'success', 'boycotting', 'caf', 'golden', 'era', 'mahmoud', 'taher', 'era', 'mahmoud', 'el', 'khatib', 'era', 'return', 'african', 'success', 'rivalries', 'supporters', 'toggle', 'supporters', 'subsection', 'ultras', 'ahlawy', 'supporting', 'groups', 'port', 'said', '
# ...

# %%
pr.Lemmatization()
# Out:
# ['al', 'ahly', 'sc', 'wikipedia', 'jump', 'content', 'main', 'menu', 'main', 'menu', 'move', 'sidebar', 'hide', 'navigation', 'main', 'pagecontentscurrent', 'eventsrandom', 'articleabout', 'wikipediacontact', 'usdonate', 'contribute', 'helplearn', 'editcommunity', 'portalrecent', 'changesupload', 'file', 'search', 'search', 'create', 'account', 'log', 'personal', 'tool', 'create', 'account', 'log', 'page', 'logged', 'editor', 'learn', 'contributionstalk', 'content', 'move', 'sidebar', 'hide', 'top', 'history', 'toggle', 'history', 'subsection', 'establishment', 'start', 'club', 'first', 'title', 'dominating', 'league', 'first', 'participation', 'african', 'championship', 'african', 'success', 'arab', 'tournament', 'success', 'boycotting', 'caf', 'golden', 'era', 'mahmoud', 'taher', 'era', 'mahmoud', 'el', 'khatib', 'era', 'return', 'african', 'success', 'rivalry', 'supporter', 'toggle', 'supporter', 'subsection', 'ultras', 'ahlawy', 'supporting', 'group', 'port', 'said', 'stadium', '
# ...

# %%
pr.del_char()

# %%
x = pr.unique_words()

# %%
print(x)
# Out:
# {'vtecaf', 'contributionstalk', 'retrieved', 'percy', 'usm', 'position', 'sarabah', 'lifted', 'committee', 'tennis', 'borg', 'khashaba', 'specifically', 'handing', 'sportive', 'unable', 'worldwide', 'norsk', 'modern', 'scored', 'abdul', 'large', 'extra', 'decision', 'psychologist', 'horoya', 'mar', 'led', 'rad', 'rough', 'talamza', 'met', 'revolution', 'esperance', 'start', 'karim', 'north', 'physiotherapist', 'mimi', 'left', 'planned', 'responsible', 'unprecedented', 'stade', 'five', 'page', 'additionally', 'ccc', 'loss', 'nabil', 'mercatoday', 'egyptsports', 'afc', 'tun', 'taha', 'went', 'abdelmohsen', 'stormed', 'vteal', 'helplearn', 'super', 'org', 'fi', 'lack', 'masry', 'tanzania', 'allow', 'behind', 'mahalla', 'menu', 'gk', 'owned', 'consistent', 'ga', 'tetch', 'sacked', 'later', 'seri', 'sporta', 'wikidataofficial', 'however', 'available', 'lion', 'star', 'becoming', 'red', 'follower', 'sounder', 'abdulaziz', 'net', 'gha', 'television', 'crowd', 'anthem', 'leg', 'driven', 'rev
# ...
